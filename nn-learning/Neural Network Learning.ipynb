# %% [markdown]
# # Neural Network Learning

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
from display_data import *
from sigmoid import *
from nn_cross_entropy import *

# %%
data = loadmat('ex4data.mat')
X = data['X']
y = data['y']

m, n = X.shape
input_layer_size = 400
hidden_layer_size = 25
labels = 10
Lambda = 3

random_indices = np.random.randint(0, m, size=100)
vis_data = X[random_indices, :]

# %%
display_data(vis_data);

# %%
nn_params = loadmat('ex4weights.mat')

# %%
nn_cross_entropy_loss(nn_params, input_layer_size, hidden_layer_size, labels, X, y, Lambda)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-e0be4ac1bff6> in <module>
# ----> 1 nn_cross_entropy_loss(nn_params, input_layer_size, hidden_layer_size, labels, X, y, Lambda)
#
# C:\projects\statml\nn-learning\nn_cross_entropy.py in nn_cross_entropy_loss(params, input_layer_size, hidden_layer_size, labels, X, y, Lambda)
#      12     a1 = np.concatenate((np.ones((m, 1)), X), -1)
#      13     z2 = np.dot(a1, np.transpose(theta1))
# ---> 14     a2 = np.concatenate((np.ones((m, 1)), sigmoid(z2), -1))
#      15     z3 = np.dot(a2, np.transpose(theta2))
#      16     a3 = sigmoid(z3)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 1 and the array at index 1 has size 25
